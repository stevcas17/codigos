# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianRangel99/SeminarioBigData/blob/main/Laboratorio2/Laboratorio_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
flights_file1 = "/content/drive/MyDrive/Combined_Flights_2018.parquet"
flights_file2 = "/content/drive/MyDrive/Combined_Flights_2019.parquet"
flights_file3 = "/content/drive/MyDrive/Combined_Flights_2020.parquet"
#flights_file4 = "/content/drive/MyDrive/Combined_Flights_2021.parquet"
#flights_file5 = "/content/drive/MyDrive/Combined_Flights_2022.parquet"
df1 = pd.read_parquet(flights_file1)
df2 = pd.read_parquet(flights_file2)
df3 = pd.read_parquet(flights_file3)
#df4 = pd.read_parquet(flights_file4)
#df5 = pd.read_parquet(flights_file5)

# %%
# df = pd.concat([df3, df5])
df = df3

# %%
# %%timeit

df_agg = df.groupby(['Airline','Year'])[["DepDelayMinutes", "ArrDelayMinutes"]].agg(
    ["mean", "sum", "max"]
)
df_agg = df_agg.reset_index()
df_agg.to_parquet("temp_pandas.parquet")

# %%
# !ls -GFlash temp_pandas.parquet
# Out:
# 12K -rw-r--r-- 1 root 9.0K Jul 17 02:29 temp_pandas.parquet

# %%
pd.read_parquet('temp_pandas.parquet')
# Out:
#                                       Airline  Year DepDelayMinutes  \
#                                                                mean
# 0                 Air Wisconsin Airlines Corp  2020        8.583725
# 1                        Alaska Airlines Inc.  2020        5.818328
# 2                               Allegiant Air  2020       12.825575
# 3                      American Airlines Inc.  2020        7.624477
# 4                 Capital Cargo International  2020        7.665063
# 5                                 Comair Inc.  2020       10.068723
# 6   Commutair Aka Champlain Enterprises, Inc.  2020       12.266858
# 7                            Compass Airlines  2020        8.215550
# 8                        Delta Air Lines Inc.  2020        5.581694
# 9                        Empire Airlines Inc.  2020        6.861561
# 10                          Endeavor Air Inc.  2020        5.653603
# 11                                  Envoy Air  2020        6.685444
# 12                   ExpressJet Airlines Inc.  2020        6.396004
# 13                     Frontier Airlines Inc.  2020        7.398021
# 14   GoJet Airlines, LLC d/b/a United Express  2020        8.309550
# 15                     Hawaiian Airlines Inc.  2020        3.592000
# 16                                Horizon Air  2020        4.849894
# 17                            JetBlue Airways  2020        8.213825
# 18                         Mesa Airlines Inc.  2020        9.662425
# 19                          Republic Airlines  2020        5.224466
# 20                      SkyWest Airlines Inc.  2020        8.671988
# 21                     Southwest Airlines Co.  2020        4.116316
# 22                           Spirit Air Lines  2020        7.809889
# 23                      Trans States Airlines  2020       13.739364
# 24                      United Air Lines Inc.  2020        6.925499
#
#                       ArrDelayMinutes
#           sum     max            mean        sum     max
# 0    433315.0  1460.0        8.982529   452450.0  1439.0
# 1    772930.0   823.0        6.365082   843157.0   788.0
# 2   1080016.0  1648.0       13.331111  1115734.0  1645.0
# 3   4084097.0  3890.0        7.861155  4202644.0  3864.0
# 4    512969.0  1482.0        8.427212   561522.0  1470.0
# 5   1798294.0  1919.0       10.686808  1903235.0  1888.0
# 6    385670.0  1557.0       13.438158   421340.0  1555.0
# 7    120670.0  1431.0        8.641498   126693.0  1412.0
# 8   3083283.0  1195.0        6.209070  3424414.0  1193.0
# 9     32613.0   274.0        7.028136    33222.0   272.0
# 10  1156405.0  2579.0        5.877866  1200707.0  2560.0
# 11  1339382.0  2248.0        8.417206  1682490.0  2238.0
# 12   308249.0  1357.0        7.443095   357797.0  1338.0
# 13   640062.0   645.0        7.330406   633479.0   638.0
# 14   304786.0  1408.0        8.336411   305196.0  1382.0
# 15   137491.0  1484.0        4.092661   156487.0  1481.0
# 16   445133.0   775.0        5.351232   489932.0   758.0
# 17  1118838.0  1135.0        8.503231  1155334.0  1153.0
# 18  1236887.0  1890.0       10.344427  1320704.0  1884.0
# 19  1093533.0  1352.0        5.824160  1216865.0  1381.0
# 20  4963057.0  2327.0        8.718970  4976457.0  2308.0
# 21  3637115.0   602.0        3.372148  2975631.0   597.0
# 22  1032194.0  1339.0        7.758486  1023290.0  1262.0
# 23   235108.0  1390.0       14.784864   252008.0  1366.0
# 24  1978518.0  1471.0        6.766355  1929514.0  1503.0

# %%
pd.read_parquet('temp_pandas.parquet').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   (Airline, )              25 non-null     object
#  1   (Year, )                 25 non-null     int64
#  2   (DepDelayMinutes, mean)  25 non-null     float64
#  3   (DepDelayMinutes, sum)   25 non-null     float64
#  4   (DepDelayMinutes, max)   25 non-null     float64
#  5   (ArrDelayMinutes, mean)  25 non-null     float64
#  6   (ArrDelayMinutes, sum)   25 non-null     float64
#  7   (ArrDelayMinutes, max)   25 non-null     float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 1.7+ KB

# %%
import polars as pl

# %%
flights_file1 = "/content/drive/MyDrive/Combined_Flights_2018.parquet"
flights_file2 = "/content/drive/MyDrive/Combined_Flights_2019.parquet"
flights_file3 = "/content/drive/MyDrive/Combined_Flights_2020.parquet"
flights_file4 = "/content/drive/MyDrive/Combined_Flights_2021.parquet"
flights_file5 = "/content/drive/MyDrive/Combined_Flights_2022.parquet"
df1 = pl.scan_parquet(flights_file1)
df2 = pl.scan_parquet(flights_file2)
df3 = pl.scan_parquet(flights_file3)
df4 = pl.scan_parquet(flights_file4)
df5 = pl.scan_parquet(flights_file5)

# %%
# %%timeit

df_polars = (
    pl.concat([df1, df2, df3, df4, df5])
    .groupby(['Airline', 'Year'])
    .agg([
        pl.col("DepDelayMinutes").mean().alias("avg_dep_delay"),
        pl.col("DepDelayMinutes").sum().alias("sum_dep_delay"),
        pl.col("DepDelayMinutes").max().alias("max_dep_delay"),
        pl.col("ArrDelayMinutes").mean().alias("avg_arr_delay"),
        pl.col("ArrDelayMinutes").sum().alias("sum_arr_delay"),
        pl.col("ArrDelayMinutes").max().alias("max_arr_delay"),
      ])
).collect()

df_polars.write_parquet('temp_polars.parquet')
# Out:
# <magic-timeit>:3: DeprecationWarning: `groupby` is deprecated. It has been renamed to `group_by`.
# 11.4 s ± 2.56 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# !ls -GFlash temp_polars.parquet
# Out:
# 8.0K -rw-r--r-- 1 root 8.0K Jul  3 00:04 temp_polars.parquet

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488491 sha256=83280c0fe827d60f90bfb5ab658d191824218cbb970de3570a3d058b234b23c4
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import avg, max, sum, concat

# %%
spark = SparkSession.builder.master("local[1]").appName("airline-example").getOrCreate()

# %%
flights_file1 = "/content/drive/MyDrive/Combined_Flights_2018.parquet"
flights_file2 = "/content/drive/MyDrive/Combined_Flights_2019.parquet"
flights_file3 = "/content/drive/MyDrive/Combined_Flights_2020.parquet"
flights_file4 = "/content/drive/MyDrive/Combined_Flights_2021.parquet"
flights_file5 = "/content/drive/MyDrive/Combined_Flights_2022.parquet"

# %%
df_spark1 = spark.read.parquet(flights_file1)
df_spark2 = spark.read.parquet(flights_file2)
df_spark3 = spark.read.parquet(flights_file3)
df_spark4 = spark.read.parquet(flights_file4)
df_spark5 = spark.read.parquet(flights_file5)

# %%
df_spark = df_spark1.union(df_spark2)
df_spark = df_spark.union(df_spark3)
df_spark = df_spark.union(df_spark4)
df_spark = df_spark.union(df_spark5)

# %%
df_spark_agg = df_spark.groupby("Airline", "Year").agg(
    avg("ArrDelayMinutes").alias('avg_arr_delay'),
    sum("ArrDelayMinutes").alias('sum_arr_delay'),
    max("ArrDelayMinutes").alias('max_arr_delay'),
    avg("DepDelayMinutes").alias('avg_dep_delay'),
    sum("DepDelayMinutes").alias('sum_dep_delay'),
    max("DepDelayMinutes").alias('max_dep_delay'),
)
df_spark_agg.write.mode('overwrite').parquet('temp_spark.parquet')

# %%
# !ls -GFlash temp_pyspark.parquet
# Out:
# ls: cannot access 'temp_pyspark.parquet': No such file or directory

# %%
import pandas as pd
import dask.dataframe as dd
flights_file1 = "/content/drive/MyDrive/Combined_Flights_2018.parquet"
flights_file2 = "/content/drive/MyDrive/Combined_Flights_2019.parquet"
flights_file3 = "/content/drive/MyDrive/Combined_Flights_2020.parquet"
flights_file4 = "/content/drive/MyDrive/Combined_Flights_2021.parquet"
flights_file5 = "/content/drive/MyDrive/Combined_Flights_2022.parquet"
df1 = dd.read_parquet(flights_file1)
df2 = dd.read_parquet(flights_file2)
df3 = dd.read_parquet(flights_file3)
df4 = dd.read_parquet(flights_file4)
df5 = dd.read_parquet(flights_file5)

# %%
df = dd.concat([df3, df5])

# %%
print(df.compute())
# Out:
#        FlightDate            Airline Origin Dest  Cancelled  Diverted  \
# 0      2020-09-01        Comair Inc.    PHL  DAY      False     False
# 1      2020-09-02        Comair Inc.    PHL  DAY      False     False
# 2      2020-09-03        Comair Inc.    PHL  DAY      False     False
# 3      2020-09-04        Comair Inc.    PHL  DAY      False     False
# 4      2020-09-05        Comair Inc.    PHL  DAY      False     False
# ...           ...                ...    ...  ...        ...       ...
# 590537 2022-03-31  Republic Airlines    MSY  EWR      False      True
# 590538 2022-03-17  Republic Airlines    CLT  EWR       True     False
# 590539 2022-03-08  Republic Airlines    ALB  ORD      False     False
# 590540 2022-03-25  Republic Airlines    EWR  PIT      False      True
# 590541 2022-03-07  Republic Airlines    EWR  RDU      False      True
#
#         CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  WheelsOff  \
# 0             1905   1858.0              0.0      -7.0  ...     1914.0
# 1             1905   1858.0              0.0      -7.0  ...     1914.0
# 2             1905   1855.0              0.0     -10.0  ...     2000.0
# 3             1905   1857.0              0.0      -8.0  ...     1910.0
# 4             1905   1856.0              0.0      -9.0  ...     1910.0
# ...            ...      ...              ...       ...  ...        ...
# 590537        1949   2014.0             25.0      25.0  ...     2031.0
# 590538        1733   1817.0             44.0      44.0  ...        NaN
# 590539        1700   2318.0            378.0     378.0  ...     2337.0
# 590540        2129   2322.0            113.0     113.0  ...     2347.0
# 590541        1154   1148.0              0.0      -6.0  ...     1201.0
#
#         WheelsOn  TaxiIn  CRSArrTime  ArrDelay  ArrDel15  ArrivalDelayGroups  \
# 0         2030.0     4.0        2056     -22.0       0.0                -2.0
# 1         2022.0     5.0        2056     -29.0       0.0                -2.0
# 2         2117.0     5.0        2056      26.0       1.0                 1.0
# 3         2023.0     4.0        2056     -29.0       0.0                -2.0
# 4         2022.0     4.0        2056     -30.0       0.0                -2.0
# ...          ...     ...         ...       ...       ...                 ...
# 590537     202.0    32.0        2354       NaN       NaN                 NaN
# 590538       NaN     NaN        1942       NaN       NaN                 NaN
# 590539      52.0     7.0        1838     381.0       1.0                12.0
# 590540     933.0     6.0        2255       NaN       NaN                 NaN
# 590541    1552.0     4.0        1333       NaN       NaN                 NaN
#
#         ArrTimeBlk  DistanceGroup  DivAirportLandings
# 0        2000-2059              2                 0.0
# 1        2000-2059              2                 0.0
# 2        2000-2059              2                 0.0
# 3        2000-2059              2                 0.0
# 4        2000-2059              2                 0.0
# ...            ...            ...                 ...
# 590537   2300-2359              5                 1.0
# 590538   1900-1959              3                 0.0
# 590539   1800-1859              3                 0.0
# 590540   2200-2259              2                 1.0
# 590541   1300-1359              2                 1.0
#
# [9100715 rows x 61 columns]

# %%
df = df.compute()

# %%
# %%timeit

df_agg = df.groupby(['Airline','Year'])[["DepDelayMinutes", "ArrDelayMinutes"]].agg(
    ["mean", "sum", "max"]
)
df_agg = df_agg.reset_index()
df_agg.to_parquet("temp_dask.parquet")

# %%
# !ls -GFlash temp_pandas.parquet
# Out:
# 12K -rw-r--r-- 1 root 9.1K Jul  3 00:00 temp_pandas.parquet

# %%
pd.read_parquet('temp_dask.parquet').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   (Airline, )              46 non-null     string
#  1   (Year, )                 46 non-null     int64
#  2   (DepDelayMinutes, mean)  46 non-null     float64
#  3   (DepDelayMinutes, sum)   46 non-null     float64
#  4   (DepDelayMinutes, max)   46 non-null     float64
#  5   (ArrDelayMinutes, mean)  46 non-null     float64
#  6   (ArrDelayMinutes, sum)   46 non-null     float64
#  7   (ArrDelayMinutes, max)   46 non-null     float64
# dtypes: float64(6), int64(1), string(1)
# memory usage: 3.0 KB

# %%
pd.read_parquet('temp_dask.parquet')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-e449c2b6db1c> in <cell line: 1>()
# ----> 1 pd.read_parquet('temp_dask.parquet')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, **kwargs)
#     507     check_dtype_backend(dtype_backend)
#     508
# --> 509     return impl.read(
#     510         path,
#     511         columns=columns,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in read(self, path, columns, use_nullable_dtypes, dtype_backend, storage_options, **kwargs)
#     218             to_pandas_kwargs["split_blocks"] = True  # type: ignore[assignment]
#     219
# --> 220         path_or_handle, handles, kwargs["filesystem"] = _get_path_or_handle(
#     221             path,
#     222             kwargs.pop("filesystem", None),
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     108         # fsspec resources can also point to directories
#     109         # this branch is used for example when reading from non-fsspec URLs
# --> 110         handles = get_handle(
#     111             path_or_handle, mode, is_text=False, storage_options=storage_options
#     112         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     866         else:
#     867             # Binary mode
# --> 868             handle = open(handle, ioargs.mode)
#     869         handles.append(handle)
#     870
#
# FileNotFoundError: [Errno 2] No such file or directory: 'temp_dask.parquet'

# %%
import pandas as pd

# %%
agg_pandas = pd.read_parquet('temp_pandas.parquet')
agg_polars = pd.read_parquet('temp_polars.parquet')
agg_spark = pd.read_parquet('temp_spark.parquet')
agg_dask = pd.read_parquet('temp_dask.parquet')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-c609c7c68be8> in <cell line: 2>()
#       1 agg_pandas = pd.read_parquet('temp_pandas.parquet')
# ----> 2 agg_polars = pd.read_parquet('temp_polars.parquet')
#       3 agg_spark = pd.read_parquet('temp_spark.parquet')
#       4 agg_dask = pd.read_parquet('temp_dask.parquet')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, **kwargs)
#     507     check_dtype_backend(dtype_backend)
#     508
# --> 509     return impl.read(
#     510         path,
#     511         columns=columns,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in read(self, path, columns, use_nullable_dtypes, dtype_backend, storage_options, **kwargs)
#     218             to_pandas_kwargs["split_blocks"] = True  # type: ignore[assignment]
#     219
# --> 220         path_or_handle, handles, kwargs["filesystem"] = _get_path_or_handle(
#     221             path,
#     222             kwargs.pop("filesystem", None),
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     108         # fsspec resources can also point to directories
#     109         # this branch is used for example when reading from non-fsspec URLs
# --> 110         handles = get_handle(
#     111             path_or_handle, mode, is_text=False, storage_options=storage_options
#     112         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     866         else:
#     867             # Binary mode
# --> 868             handle = open(handle, ioargs.mode)
#     869         handles.append(handle)
#     870
#
# FileNotFoundError: [Errno 2] No such file or directory: 'temp_polars.parquet'

# %%
agg_pandas.shape, agg_polars.shape, agg_spark.shape, agg_dask.shape
# Out:
# ((26, 8), (122, 8), (122, 8), (46, 8))

# %%
agg_pandas.shape, agg_polars.shape, agg_spark.shape, agg_dask.shape
# Out:
# ((26, 8), (122, 8), (122, 8), (46, 8))

# %%
agg_pandas.sort_values(['Airline','Year']).head()
# Out:
#                        Airline  Year DepDelayMinutes                      \
#                                                 mean         sum     max
# 0  Air Wisconsin Airlines Corp  2019       16.868511   1742281.0  1690.0
# 1         Alaska Airlines Inc.  2019        9.836041   2576246.0  1117.0
# 2                Allegiant Air  2019       14.678433   1536876.0  1979.0
# 3       American Airlines Inc.  2019       14.895515  13814816.0  2315.0
# 4  Capital Cargo International  2019       11.525332   1367642.0  1182.0
#
#   ArrDelayMinutes
#              mean         sum     max
# 0       17.610384   1811545.0  1707.0
# 1       10.787284   2815643.0  1087.0
# 2       15.556524   1624770.0  1966.0
# 3       15.251863  14096412.0  2350.0
# 4       12.489465   1474806.0  1190.0

# %%
agg_polars.sort_values(['Airline','Year']).head()
# Out:
#                          Airline  Year  avg_dep_delay  sum_dep_delay  \
# 98   Air Wisconsin Airlines Corp  2018      16.753459      1606774.0
# 103  Air Wisconsin Airlines Corp  2019      16.868511      1742281.0
# 104  Air Wisconsin Airlines Corp  2020       8.583725       433315.0
# 110  Air Wisconsin Airlines Corp  2021      16.553045      1290194.0
# 93   Air Wisconsin Airlines Corp  2022      13.124801       510581.0
#
#      max_dep_delay  avg_arr_delay  sum_arr_delay  max_arr_delay
# 98          1296.0      17.881934      1708887.0         1292.0
# 103         1690.0      17.610384      1811545.0         1707.0
# 104         1460.0       8.982529       452450.0         1439.0
# 110         1421.0      17.327440      1346602.0         1416.0
# 93          1355.0      13.340409       517261.0         1353.0

# %%
agg_dask.sort_values(['Airline','Year']).head()
# Out:
#                        Airline  Year DepDelayMinutes                     \
#                                                 mean        sum     max
# 0  Air Wisconsin Airlines Corp  2020        8.583725   433315.0  1460.0
# 1  Air Wisconsin Airlines Corp  2022       13.124801   510581.0  1355.0
# 2         Alaska Airlines Inc.  2020        5.818328   772930.0   823.0
# 3         Alaska Airlines Inc.  2022       10.153994  1278134.0   915.0
# 4                Allegiant Air  2020       12.825575  1080016.0  1648.0
#
#   ArrDelayMinutes
#              mean        sum     max
# 0        8.982529   452450.0  1439.0
# 1       13.340409   517261.0  1353.0
# 2        6.365082   843157.0   788.0
# 3       11.026280  1382905.0   908.0
# 4       13.331111  1115734.0  1645.0
